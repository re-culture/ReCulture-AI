# %%
import torch
from torch_geometric.data import Data

edge_index = torch.tensor([[0, 1], [1, 2]], dtype=torch.long)

x_user = torch.tensor([[1], [2]], dtype=torch.float)
x_record = torch.tensor([[1], [2]], dtype=torch.float)
x = torch.cat([x_user, x_record], dim=0)

data = Data(x=x, edge_index=edge_index.t().contiguous())
print(data)
# Out:
# Data(x=[4, 1], edge_index=[2, 2])

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(in_channels, 16)
        self.conv2 = GCNConv(16, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

# %%
model = GCN(in_channels=1, out_channels=2)  # 입력 채널과 출력 채널 설정
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

model.train()
for epoch in range(200):
    optimizer.zero_grad()
    out = model(data)
    loss = F.nll_loss(out, data.edge_index)
    loss.backward()
    optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 model = GCN(in_channels=1, out_channels=2)  # 입력 채널과 출력 채널 설정
#       2 optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
#       4 model.train()
#
# TypeError: __init__() got an unexpected keyword argument 'in_channels'

# %%
model.eval()
_, pred = model(data).max(dim=1)
print(pred)
# Out:
# tensor([0, 0, 0, 0])

# %% [markdown]
# ### GNN Recommendation

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# CSV 파일 불러오기
all_reviews = pd.read_csv('all_reviews.csv')

category_name = [ "", "영화", "뮤지컬", "연극", "스포츠", "공연", "드라마", "책", "전시"]

all_reviews['category_name'] = all_reviews['category'].apply(lambda x: category_name[x])
# 제목과 내용을 결합하여 하나의 텍스트로 생성
all_reviews['all_text'] = all_reviews['category_name'] + ' ' + all_reviews['title'] + ' ' + all_reviews['content']

# TF-IDF 벡터화
tfidf_vectorizer = TfidfVectorizer(max_features=500)
tfidf_matrix = tfidf_vectorizer.fit_transform(all_reviews['all_text'])

# 코사인 유사도 계산
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
import torch
from torch_geometric.data import Data

# 유사도를 기반으로 엣지 생성 (유사도가 일정 수준 이상인 것만 연결)
edge_index = torch.tensor([
    [i, j] for i in range(len(cosine_sim)) for j in range(len(cosine_sim)) if cosine_sim[i, j] > 0.5
], dtype=torch.long).t().contiguous()

# TF-IDF 벡터를 노드 특징으로 사용
x = torch.tensor(tfidf_matrix.toarray(), dtype=torch.float)

# 그래프 데이터 객체 생성
data = Data(x=x, edge_index=edge_index)
print(data.x.shape)
# Out:
# torch.Size([3417, 500])

# %%
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

# GCN 모델 정의
class GCN(torch.nn.Module):
    def __init__(self):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(500, 16)
        self.conv2 = GCNConv(16, 500)  # 최종 출력 차원을 원래 입력 차원으로 맞춤

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x

# 모델 학습 설정
model = GCN()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# 모델 학습 과정
def train():
    model.train()
    optimizer.zero_grad()
    out = model(data)
    loss = F.mse_loss(out, data.x)  # 차원이 맞춰진 후의 MSE Loss
    loss.backward()
    optimizer.step()

# 학습 반복
for epoch in range(100):
    train()

# %%
# from flask import Flask, request, jsonify
import numpy as np

#app = Flask(__name__)

# API로 유사한 기록 추천
# @app.route('/recommend', methods=['POST'])
def recommend():
    #user_data = request.json['user_text']  # 사용자가 쓴 텍스트 입력
    user_data = {
        'title': '엘지 우승가자',
        'content': '이영빈 선수 백투백 홈런 인생경기다!',
        'category': '스포츠'
    }
    user_data = user_data['category'] + " " + user_data['title'] + " " + user_data['content']
    user_vector = tfidf_vectorizer.transform([user_data])

    # 코사인 유사도 계산
    user_sim = cosine_similarity(user_vector, tfidf_matrix)

    # 유사도 순으로 추천 (상위 5개 추천)
    recommended_indices = np.argsort(-user_sim[0])
    recommendations = all_reviews.iloc[recommended_indices]

    return recommendations.to_dict(orient='records')

#if __name__ == '__main__':
#    app.run(debug=True)

# %%
recommend()
# Out:
# [{'title': '여름에 시원한 야구장',
#   'content': '쾌적하고 좋네요 시원합니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 여름에 시원한 야구장 쾌적하고 좋네요 시원합니다'},
#  {'title': '최강두산..ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ',
#   'content': 'ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최강두산..ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ'},
#  {'title': '최강두산 승리고고',
#   'content': 'ggggggggg',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최강두산 승리고고 ggggggggg'},
#  {'title': '대역전승 ㅜㅜ',
#   'content': '너무짜릿했다...',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 대역전승 ㅜㅜ 너무짜릿했다...'},
#  {'title': '두산최고',
#   'content': 'ㅎㅎㅎㅎㅎㅎㅎ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 두산최고 ㅎㅎㅎㅎㅎㅎㅎ'},
#  {'title': '이겼다리 ㅎㅎㅎ',
#   'content': 'ㄴㅇㅁㅀㅈㄷㄺㄴㅇㅁㄹㅇㅌㅊㄴㅍㅊㅌ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 이겼다리 ㅎㅎㅎ ㄴㅇㅁㅀㅈㄷㄺㄴㅇㅁㄹㅇㅌㅊㄴㅍㅊㅌ'},
#  {'title': '굿',
#   'content': '재밌어용ㅎ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 굿 재밌어용ㅎ'},
#  {'title': 'lck',
#   'content': '더 넓은데로 가주삼',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 lck 더 넓은데로 가주삼'},
#  {'title': '재미따',
#   'content': '잼서요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 재미따 잼서요'},
#  {'title': '별ㄹ호',
#   'content': 'ㅇㄴㅁㄹㄴㄻㄻㄴㅁㄴ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 별ㄹ호 ㅇㄴㅁㄹㄴㄻㄻㄴㅁㄴ'},
#  {'title': '최고최고',
#   'content': '최고최고',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최고최고 최고최고'},
#  {'title': '변했어요 캠핑장이',
#   'content': '개인입찰후 요금은 올리고\n고기굽는 존을 맹글고\n빡빡하게 캠핑카 들여놓고 \n예약방법도 난해해지고 ㅠ\n\n매력이 없어졌어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 변했어요 캠핑장이 개인입찰후 요금은 올리고\n고기굽는 존을 맹글고\n빡빡하게 캠핑카 들여놓고 \n예약방법도 난해해지고 ㅠ\n\n매력이 없어졌어요'},
#  {'title': '베리굿 응원!!!',
#   'content': '날씨는 덥지만 활기찬 응원으로 더위를 날려버려~!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 베리굿 응원!!! 날씨는 덥지만 활기찬 응원으로 더위를 날려버려~!'},
#  {'title': '재밌...어요',
#   'content': '재밌네요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 재밌...어요 재밌네요'},
#  {'title': '미친 경기력',
#   'content': '더운 여름밤 무더위를 날려주는 경기력이였어요??',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 미친 경기력 더운 여름밤 무더위를 날려주는 경기력이였어요??'},
#  {'title': '고척돔 야구관람',
#   'content': '집에서 걸어갈수있는.고척돔.오랜만의 야구.즐거웠다\n준비해간 야채전 샌드위치 커피 과일 먹으며 남편과\n행복한시간을 보냈다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 고척돔 야구관람 집에서 걸어갈수있는.고척돔.오랜만의 야구.즐거웠다\n준비해간 야채전 샌드위치 커피 과일 먹으며 남편과\n행복한시간을 보냈다'},
#  {'title': '폭염 취소 됨',
#   'content': '...',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 폭염 취소 됨 ...'},
#  {'title': '이승엽경질',
#   'content': '이승엽경질',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 이승엽경질 이승엽경질'},
#  {'title': 'Good match',
#   'content': 'Good sight',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 Good match Good sight'},
#  {'title': '야구장',
#   'content': '더운데 재미있었습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 야구장 더운데 재미있었습니다'},
#  {'title': 'Good match',
#   'content': 'Good sight',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 Good match Good sight'},
#  {'title': '이겨줘..',
#   'content': '수��....제발 이겨줘ㅠㅠㅠㅠㅠ 심판 편파판정에도 당당해질수 있도록 노력해줘...',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 이겨줘.. 수��....제발 이겨줘ㅠㅠㅠㅠㅠ 심판 편파판정에도 당당해질수 있도록 노력해줘...'},
#  {'title': '개좃��',
#   'content': '개조�T',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 개좃�� 개조�T'},
#  {'title': '두산화이팅!!',
#   'content': '졌지만 재밌엇습니다!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 두산화이팅!! 졌지만 재밌엇습니다!'},
#  {'title': '키움 역전승했다',
#   'content': '돌아버려... 키움 역전승해서 도파민 폭발했다... \n키움히어로즈 파이팅',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 키움 역전승했다 돌아버려... 키움 역전승해서 도파민 폭발했다... \n키움히어로즈 파이팅'},
#  {'title': '오스마르 응원합니다',
#   'content': '오스마르 선수 응원합니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 오스마르 응원합니다 오스마르 선수 응원합니다'},
#  {'title': '고객센터 는 어디있는건지',
#   'content': '환불해주세요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 고객센터 는 어디있는건지 환불해주세요'},
#  {'title': '자가텐트6.7번',
#   'content': '토요일1박하고.올해는.너무더워서.일요일.아침일직철수.해씀니다.물썰매장.수영장개장안해서.아시워씀니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 자가텐트6.7번 토요일1박하고.올해는.너무더워서.일요일.아침일직철수.해씀니다.물썰매장.수영장개장안해서.아시워씀니다'},
#  {'title': '연천 재인폭포 카라반',
#   'content': '최고예요.  깨끗해요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 연천 재인폭포 카라반 최고예요.  깨끗해요'},
#  {'title': '노을파크골장',
#   'content': '잔다리 관리 좀 해 주세요\n부탁드립니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 노을파크골장 잔다리 관리 좀 해 주세요\n부탁드립니다'},
#  {'title': '직관후기',
#   'content': '김택연 사랑해',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 직관후기 김택연 사랑해'},
#  {'title': '가깝고 재밌었습니다 진게 아쉽지만',
#   'content': '예매도 편히하고 자리도 나쁘지않았습니다\n가성비너무좋은자리였던 \n단지 경기를 진게 아쉬웠어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 가깝고 재밌었습니다 진게 아쉽지만 예매도 편히하고 자리도 나쁘지않았습니다\n가성비너무좋은자리였던 \n단지 경기를 진게 아쉬웠어요'},
#  {'title': '키움 직관',
#   'content': '키움 만세',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 키움 직관 키움 만세'},
#  {'title': '무지더웠지만 재밌다',
#   'content': '무지더웠지만 재밌었다 .\n다음날 폭염으로 경기취소~~  행운의 사나이. \n굿럭',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 무지더웠지만 재밌다 무지더웠지만 재밌었다 .\n다음날 폭염으로 경기취소~~  행운의 사나이. \n굿럭'},
#  {'title': '꿀잼',
#   'content': '또 갈거임',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 꿀잼 또 갈거임'},
#  {'title': '강력추천',
#   'content': '모바일 티켓으로 별도 발행없이 잘 다녀옴',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 강력추천 모바일 티켓으로 별도 발행없이 잘 다녀옴'},
#  {'title': '최강기아??????????',
#   'content': '기아사랑해',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최강기아?????????? 기아사랑해'},
#  {'title': '두산 엘지',
#   'content': '응 두산이 발라욘',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 두산 엘지 응 두산이 발라욘'},
#  {'title': '나쁘지않음',
#   'content': '주변에편의점같은게없는게좀아쉽',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 나쁘지않음 주변에편의점같은게없는게좀아쉽'},
#  {'title': '뜻깊은승리 첫 미르스타디움',
#   'content': '미르스타디움 깨끗하고 쾌적한경기였네요.\n굿굿',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 뜻깊은승리 첫 미르스타디움 미르스타디움 깨끗하고 쾌적한경기였네요.\n굿굿'},
#  {'title': 'ㅠㅠ너무 재미있엇따',
#   'content': '2대0으로 이겨서 더 좋앗음',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 ㅠㅠ너무 재미있엇따 2대0으로 이겨서 더 좋앗음'},
#  {'title': '깨끗하네요',
#   'content': '잘 이용하고 갔습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 깨끗하네요 잘 이용하고 갔습니다'},
#  {'title': '강민희해설사님최고',
#   'content': '친절하고 재밋으셔요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 강민희해설사님최고 친절하고 재밋으셔요'},
#  {'title': '키움아 응원한다~',
#   'content': '엘팬이지만 친구네 팀이라 응원하구요\n기아 이겨줘서 고마웠어요..ㅠㅜ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 키움아 응원한다~ 엘팬이지만 친구네 팀이라 응원하구요\n기아 이겨줘서 고마웠어요..ㅠㅜ'},
#  {'title': '이겨라 좀',
#   'content': '키움아 제발',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 이겨라 좀 키움아 제발'},
#  {'title': '맨압에서 직관',
#   'content': '가까이 선수들 보며 응원하니 더 절실하더라구요.\n오늘은 우리팀이 부진했지만 다음엔 파이팅~',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 맨압에서 직관 가까이 선수들 보며 응원하니 더 절실하더라구요.\n오늘은 우리팀이 부진했지만 다음엔 파이팅~'},
#  {'title': '최강두산...ㅎㅎㅎ',
#   'content': 'ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최강두산...ㅎㅎㅎ ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ'},
#  {'title': '최강두산...ㅎㅎㅎㅎㅎㅎㅎ',
#   'content': 'ㅎㅎㅎㅎㅎㅎㅎ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최강두산...ㅎㅎㅎㅎㅎㅎㅎ ㅎㅎㅎㅎㅎㅎㅎ'},
#  {'title': '좋아',
#   'content': '좋아용',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 좋아 좋아용'},
#  {'title': '정비필요.',
#   'content': '홀컵주변 너무엉망입니다.\n이런데서 대회를한다는게 창피합니다.\n정비후 대회개체요합니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 정비필요. 홀컵주변 너무엉망입니다.\n이런데서 대회를한다는게 창피합니다.\n정비후 대회개체요합니다'},
#  {'title': '잦밧들',
#   'content': '또 이겼다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 잦밧들 또 이겼다'},
#  {'title': '야구관람',
#   'content': '라이벌전 예매도 수월하고 티켓 예매는 인터파크티켓이 최고인것같습니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 야구관람 라이벌전 예매도 수월하고 티켓 예매는 인터파크티켓이 최고인것같습니다.'},
#  {'title': '개꿀잼',
#   'content': 'ㄹㅇ 개꿀잼 또 갈거임',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 개꿀잼 ㄹㅇ 개꿀잼 또 갈거임'},
#  {'title': '재밋당',
#   'content': '재밌어용',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 재밋당 재밌어용'},
#  {'title': '이겼다',
#   'content': '두산베어스 파이팅',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 이겼다 두산베어스 파이팅'},
#  {'title': '처음가본 글램핑',
#   'content': '안성맞춤캠핑장은 일반캠핑으로 다녀봤어요^^\n이번에는 글램핑을 운좋게잡아서 다녀왔는데 시설도 깨끗하고 편하고 너무 좋네요^^',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 처음가본 글램핑 안성맞춤캠핑장은 일반캠핑으로 다녀봤어요^^\n이번에는 글램핑을 운좋게잡아서 다녀왔는데 시설도 깨끗하고 편하고 너무 좋네요^^'},
#  {'title': '축구',
#   'content': '너무 재미있었다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 축구 너무 재미있었다'},
#  {'title': '너무덥고 너무 못하고..',
#   'content': '경기력도 너무떨어지고..\n너무덥네요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 너무덥고 너무 못하고.. 경기력도 너무떨어지고..\n너무덥네요'},
#  {'title': '카라반 에어컨 성능',
#   'content': '날이 더운탓도 있겠지만\n에어컨 용량이 적은건지 풀로 틀어도 너무 더웠네요\n바닥 청소도 미흡해서\n모래가 발에 밟혀서 물티슈로 닦았어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 카라반 에어컨 성능 날이 더운탓도 있겠지만\n에어컨 용량이 적은건지 풀로 틀어도 너무 더웠네요\n바닥 청소도 미흡해서\n모래가 발에 밟혀서 물티슈로 닦았어요'},
#  {'title': '처음가본 글램핑',
#   'content': '안성맞춤캠핑장은 일반캠핑으로 다녀봤어요^^\n이번에는 글램핑을 운좋게잡아서 다녀왔는데 시설도 깨끗하고 편하고 너무 좋네요^^',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 처음가본 글램핑 안성맞춤캠핑장은 일반캠핑으로 다녀봤어요^^\n이번에는 글램핑을 운좋게잡아서 다녀왔는데 시설도 깨끗하고 편하고 너무 좋네요^^'},
#  {'title': '고척돔구장',
#   'content': '바깥은 찌는듯한 더위지만 고척돔구장은 예외인가 봅니다. 경기내내 너무 시원했어요. 재방문할려고합니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 고척돔구장 바깥은 찌는듯한 더위지만 고척돔구장은 예외인가 봅니다. 경기내내 너무 시원했어요. 재방문할려고합니다.'},
#  {'title': '야구 너무 재밌개 보구옴',
#   'content': '인터파크덕에 매일 편하게 표사고 다녀옵니더 한화화이팅!!!!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 야구 너무 재밌개 보구옴 인터파크덕에 매일 편하게 표사고 다녀옵니더 한화화이팅!!!!'},
#  {'title': '너무 무기력하게 졌어요ㅜㅜ',
#   'content': '질질...끌려가는..',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 너무 무기력하게 졌어요ㅜㅜ 질질...끌려가는..'},
#  {'title': '승리의 KT',
#   'content': '정말 최고였어요????',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 승리의 KT 정말 최고였어요????'},
#  {'title': '음. ..',
#   'content': '이겼으면 더 좋았을걸.\n많이 아쉽네. ..',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 음. .. 이겼으면 더 좋았을걸.\n많이 아쉽네. ..'},
#  {'title': '최고였어요!!!',
#   'content': '롤파크 직관 진짜 최고예요!!!!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최고였어요!!! 롤파크 직관 진짜 최고예요!!!!'},
#  {'title': '좋았습니다',
#   'content': '역대급경기한번만들어주는구나',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 좋았습니다 역대급경기한번만들어주는구나'},
#  {'title': '직관',
#   'content': '이겨서 좋았습니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 직관 이겨서 좋았습니다.'},
#  {'title': '행복했습니다.',
#   'content': '평일이고 더웠지만 승리해서 좋았습니다~',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 행복했습니다. 평일이고 더웠지만 승리해서 좋았습니다~'},
#  {'title': '너무덥지만 이겨서 좋아요',
#   'content': '너무더웠지만 이겨서 좋아여',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 너무덥지만 이겨서 좋아요 너무더웠지만 이겨서 좋아여'},
#  {'title': '좋아요^^',
#   'content': '합리적 가격. 친철한 직원분들\n모는것에 만족해요^^',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 좋아요^^ 합리적 가격. 친철한 직원분들\n모는것에 만족해요^^'},
#  {'title': '돔구장',
#   'content': '시원하고 좋아요~~~',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 돔구장 시원하고 좋아요~~~'},
#  {'title': '좋아요',
#   'content': 'Awesome!!!잠실 라이벌전다운 치열했던 경기두산은 역전을 허용하지 않았고 엘지는 따라가지 못했다!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 좋아요 Awesome!!!잠실 라이벌전다운 치열했던 경기두산은 역전을 허용하지 않았고 엘지는 따라가지 못했다!'},
#  {'title': '간편하고 좋아요',
#   'content': '비록 지긴했지만 재미있었어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 간편하고 좋아요 비록 지긴했지만 재미있었어요'},
#  {'title': '자리가 좋아요',
#   'content': '선수들 숨소리까지 들려요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 자리가 좋아요 선수들 숨소리까지 들려요'},
#  {'title': '빠른입장은',
#   'content': '역시 모바일 티켓이죠 ^^',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 빠른입장은 역시 모바일 티켓이죠 ^^'},
#  {'title': '잘보고 왔어요',
#   'content': '모바일티켓이 확실히 편한거 같아요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 잘보고 왔어요 모바일티켓이 확실히 편한거 같아요'},
#  {'title': '잘보고왔습니다',
#   'content': '재밌게 잘 즐겼습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 잘보고왔습니다 재밌게 잘 즐겼습니다'},
#  {'title': '단체 응원',
#   'content': '그냥 저냥',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 단체 응원 그냥 저냥'},
#  {'title': '온수파크',
#   'content': '나오는이 온수임\n실외더워서가아니라 그냥 온수물이나옴\n샤워실이젤시원함',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 온수파크 나오는이 온수임\n실외더워서가아니라 그냥 온수물이나옴\n샤워실이젤시원함'},
#  {'title': '?',
#   'content': '그냥 보지를 못했는데 어쩌라고',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 ? 그냥 보지를 못했는데 어쩌라고'},
#  {'title': '두산대엘지',
#   'content': '초반에 대량실점이 승패를 결정했다.\n두팀은 쉽게 승부가 나지않는다\n아쉽지만 2,3차전 승리로 윈닝시리즈로 마무리',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 두산대엘지 초반에 대량실점이 승패를 결정했다.\n두팀은 쉽게 승부가 나지않는다\n아쉽지만 2,3차전 승리로 윈닝시리즈로 마무리'},
#  {'title': '새로운 세계를 보았다',
#   'content': '재미따 크크',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 새로운 세계를 보았다 재미따 크크'},
#  {'title': '다 좋은데 샤워장 불만족',
#   'content': '샤워대수가 부족하고 9시부터10시까지 청소시간\n씻을시간인데 청소를 하다니ㅜ \n11시부터 청소 시간 변경 하는게 좋을것 같아ㅛ\n\n샤워대수가 6개인데 1개는 고장 \n부족해서 대기하고있는중',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 다 좋은데 샤워장 불만족 샤워대수가 부족하고 9시부터10시까지 청소시간\n씻을시간인데 청소를 하다니ㅜ \n11시부터 청소 시간 변경 하는게 좋을것 같아ㅛ\n\n샤워대수가 6개인데 1개는 고장 \n부족해서 대기하고있는중'},
#  {'title': '야구장은 언제나 옳다',
#   'content': 'LG 원정 경기라 응원석 예매하고 응원했는데 목 터지도록 한 듯....... 어쩌면 나 야구장을 좋아하는 걸지도?',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 야구장은 언제나 옳다 LG 원정 경기라 응원석 예매하고 응원했는데 목 터지도록 한 듯....... 어쩌면 나 야구장을 좋아하는 걸지도?'},
#  {'title': '수원삼성짱',
#   'content': '미르에서 직관은 처음인데 시설도 좋고 깔끔하고 승리해서 더더욱 좋습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 수원삼성짱 미르에서 직관은 처음인데 시설도 좋고 깔끔하고 승리해서 더더욱 좋습니다'},
#  {'title': '야구 데이트?ㅎㅎ',
#   'content': '동생이랑 야구장갔어요ㅎㅎ끝날때쯤 비가왔는데 비 맞으면서 치킨먹고 나름 낭만?ㅎㅎ잼났어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 야구 데이트?ㅎㅎ 동생이랑 야구장갔어요ㅎㅎ끝날때쯤 비가왔는데 비 맞으면서 치킨먹고 나름 낭만?ㅎㅎ잼났어요'},
#  {'title': '폭염에 시원하게 보내고 왔네요',
#   'content': '2인용 카라반 아담하니 너무 좋았어요\n3인 가족이 지내기에 딱 좋네요.\n다음에는 4인 카라반 도전해요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 폭염에 시원하게 보내고 왔네요 2인용 카라반 아담하니 너무 좋았어요\n3인 가족이 지내기에 딱 좋네요.\n다음에는 4인 카라반 도전해요'},
#  {'title': '고척 돔구장 직관',
#   'content': '아들이랑 고척 돔구장 직관 다녀왔어요\n\n타 팀이라 고척은 처음인데 요즘같은 날씨에는 고척 돔이 최고네요!!\n\n비록 경기는 졌지만 시원해서 아들이랑 즐겁게 응원하고 왔어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 고척 돔구장 직관 아들이랑 고척 돔구장 직관 다녀왔어요\n\n타 팀이라 고척은 처음인데 요즘같은 날씨에는 고척 돔이 최고네요!!\n\n비록 경기는 졌지만 시원해서 아들이랑 즐겁게 응원하고 왔어요'},
#  {'title': '재밌어요',
#   'content': '경기가 길어져서 힘들었지만 이겨서 다행이었어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 재밌어요 경기가 길어져서 힘들었지만 이겨서 다행이었어요'},
#  {'title': '재밌어요',
#   'content': '경기가 길어져서 힘들었지만 이겨서 다행이었어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 재밌어요 경기가 길어져서 힘들었지만 이겨서 다행이었어요'},
#  {'title': '재밌어요',
#   'content': '즐거웠어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 재밌어요 즐거웠어요'},
#  {'title': '무더위엔 고척!',
#   'content': '승리를 위한 함성~워어어어어',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 무더위엔 고척! 승리를 위한 함성~워어어어어'},
#  {'title': '재밌었어요',
#   'content': '이겨서 재밌었습니다ㅠㅠㅠㅠㅠㅠㅠㅠ~~~~~~~~',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 재밌었어요 이겨서 재밌었습니다ㅠㅠㅠㅠㅠㅠㅠㅠ~~~~~~~~'},
#  {'title': '재밌었어요',
#   'content': '또 관람예정입니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 재밌었어요 또 관람예정입니다.'},
#  {'title': '여름에 짱',
#   'content': '여름에 시원한 고척돔에서 야구보기 너무 좋아요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 여름에 짱 여름에 시원한 고척돔에서 야구보기 너무 좋아요'},
#  {'title': '전혀 안 무서움.',
#   'content': '초등 저학년 정도만 무서워할 수위.\n8시쯤 갔더니 대기만 1시간.\n덥고 습해서 언덕 길 오르느라 땀이 비오듯 흐름. \n더위가 무서웠음.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 전혀 안 무서움. 초등 저학년 정도만 무서워할 수위.\n8시쯤 갔더니 대기만 1시간.\n덥고 습해서 언덕 길 오르느라 땀이 비오듯 흐름. \n더위가 무서웠음.'},
#  {'title': '오스마르선수 응원합니다',
#   'content': '오스마르선수 멋지게 한골 \n항상 응원합니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 오스마르선수 응원합니다 오스마르선수 멋지게 한골 \n항상 응원합니다'},
#  {'title': '야구 관람.',
#   'content': '날씨는 무지 더워지만 잼잇게 잘보고 왓네요..',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 야구 관람. 날씨는 무지 더워지만 잼잇게 잘보고 왓네요..'},
#  {'title': '드디어 홈 첫승~!',
#   'content': '5월 직관이후 홈 6경기째 방문에서k2리그 2위 전남드래곤즈를 1:0으로 극적으로 이겨버렸네요아이가 내심 자기가 보러오면 계속져서 속으로 의기소침해 있었는데너무 좋아하네요~!다음 안산경기도 또 갈꺼에요~',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 드디어 홈 첫승~! 5월 직관이후 홈 6경기째 방문에서k2리그 2위 전남드래곤즈를 1:0으로 극적으로 이겨버렸네요아이가 내심 자기가 보러오면 계속져서 속으로 의기소침해 있었는데너무 좋아하네요~!다음 안산경기도 또 갈꺼에요~'},
#  {'title': '8월7일 엘지두산',
#   'content': '비록 졌지만 오랜만에 잠실 라이벌전이라 제미있었다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 8월7일 엘지두산 비록 졌지만 오랜만에 잠실 라이벌전이라 제미있었다'},
#  {'title': '취소를 경기시작 한시간 전에..',
#   'content': '5시 경긴데 4시 지나서 취소를 알려주네요..',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 취소를 경기시작 한시간 전에.. 5시 경긴데 4시 지나서 취소를 알려주네요..'},
#  {'title': '한탄강오토캠핑장 54번',
#   'content': '물놀이장 가까워서 끝으로 예약 했어요\n화장실이 멀어서 걱정했는데 55번 뒤쪽으로 간이화장실이 생겼나봐요\n에어컨도 빵빵하고 물도 시원하고 깨끗했어요\n다만 야영장 끝 쪽은 세척장. 샤워실.매점 등이 멀어서 감안하셔야 해요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 한탄강오토캠핑장 54번 물놀이장 가까워서 끝으로 예약 했어요\n화장실이 멀어서 걱정했는데 55번 뒤쪽으로 간이화장실이 생겼나봐요\n에어컨도 빵빵하고 물도 시원하고 깨끗했어요\n다만 야영장 끝 쪽은 세척장. 샤워실.매점 등이 멀어서 감안하셔야 해요'},
#  {'title': '졌지만 시원하다',
#   'content': '고척에서 보시오.. 행복해요.. 져도.. 져도.. 져도...... ㅠㅠ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 졌지만 시원하다 고척에서 보시오.. 행복해요.. 져도.. 져도.. 져도...... ㅠㅠ'},
#  {'title': '최고!!',
#   'content': '너무 재밌었어용',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최고!! 너무 재밌었어용'},
#  {'title': '두산 엘지',
#   'content': '두산이 최고다 제일 최고다 가즈아아아아아ㅏ아아아앙아ㅏㅇ앙',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 두산 엘지 두산이 최고다 제일 최고다 가즈아아아아아ㅏ아아아앙아ㅏㅇ앙'},
#  {'title': '김택연',
#   'content': '경기는 18:30분 부터 22:30분 가량에 끝난 4시간 정도 경기를 하였고 양팀의 타선들의 폭발로 매이닝 접전이였으며 점수차도 1점차게 두산의 에이스 차기 국대 마무리 김택연 선수의 5아웃 세이브로 더 짜릿한 경기였습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 김택연 경기는 18:30분 부터 22:30분 가량에 끝난 4시간 정도 경기를 하였고 양팀의 타선들의 폭발로 매이닝 접전이였으며 점수차도 1점차게 두산의 에이스 차기 국대 마무리 김택연 선수의 5아웃 세이브로 더 짜릿한 경기였습니다'},
#  {'title': '두산 vsl lg 패하긴 했지만',
#   'content': '뜨거운 응원열기 우렁찬 함성!!\n프로야구 직관은 이맛에!~~',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 두산 vsl lg 패하긴 했지만 뜨거운 응원열기 우렁찬 함성!!\n프로야구 직관은 이맛에!~~'},
#  {'title': '키움',
#   'content': '초반에 실점 많이하긴 했지만 마지막에 타선이 점수내서 그나마 볼만함',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 키움 초반에 실점 많이하긴 했지만 마지막에 타선이 점수내서 그나마 볼만함'},
#  {'title': '그나마 토요일경기에 비하면 준수했다',
#   'content': '덥지만 버틸만했던 경기',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 그나마 토요일경기에 비하면 준수했다 덥지만 버틸만했던 경기'},
#  {'title': '한달만에 본 경기!',
#   'content': '신나게 노래부르면서 집가게 해줘서 고마웠던 날',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 한달만에 본 경기! 신나게 노래부르면서 집가게 해줘서 고마웠던 날'},
#  {'title': '고척좋다',
#   'content': '고척  좋다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 고척좋다 고척  좋다'},
#  {'title': '최악의 경기',
#   'content': '차라리 취소되었어야...',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최악의 경기 차라리 취소되었어야...'},
#  {'title': '시원한 고척에서의 3연전 중 2번째 경기',
#   'content': '고척이 확실히 돔구장이라 더 시원하더라구요\nSsg 가을가보자…!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 시원한 고척에서의 3연전 중 2번째 경기 고척이 확실히 돔구장이라 더 시원하더라구요\nSsg 가을가보자…!'},
#  {'title': '이기자',
#   'content': '화이팅',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 이기자 화이팅'},
#  {'title': '화이팅',
#   'content': '화이팅입니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 화이팅 화이팅입니다'},
#  {'title': '굿',
#   'content': '키움 히어로즈 고양 히어로즈 화이팅',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 굿 키움 히어로즈 고양 히어로즈 화이팅'},
#  {'title': '화이팅',
#   'content': '저스트 화이팅입니다..',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 화이팅 저스트 화이팅입니다..'},
#  {'title': '대한민국',
#   'content': '코리아 선수 화이팅??',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 대한민국 코리아 선수 화이팅??'},
#  {'title': '대한민국',
#   'content': '코리아 선수 화이팅??',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 대한민국 코리아 선수 화이팅??'},
#  {'title': 'LG트윈스 화이팅!!',
#   'content': '무더운 날씨였지만  연패를 끊은 LG경기!! 넘 짜릿하다..  LG  연승가자~~~~~',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 LG트윈스 화이팅!! 무더운 날씨였지만  연패를 끊은 LG경기!! 넘 짜릿하다..  LG  연승가자~~~~~'},
#  {'title': '.',
#   'content': '두산 화이팅',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 . 두산 화이팅'},
#  {'title': '.',
#   'content': '공연 잘 봤습니다!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 . 공연 잘 봤습니다!'},
#  {'title': '20240801',
#   'content': '잘봤습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 20240801 잘봤습니다'},
#  {'title': '20240731',
#   'content': '잘봤습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 20240731 잘봤습니다'},
#  {'title': '20240801',
#   'content': '잘봤습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 20240801 잘봤습니다'},
#  {'title': '20240731',
#   'content': '잘봤습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 20240731 잘봤습니다'},
#  {'title': '20240801',
#   'content': '잘봤습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 20240801 잘봤습니다'},
#  {'title': '굿굿',
#   'content': '잘봤습니다!!!!!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 굿굿 잘봤습니다!!!!!'},
#  {'title': '키움히어로즈 관람후기',
#   'content': '너무 재밌었어요~!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 키움히어로즈 관람후기 너무 재밌었어요~!'},
#  {'title': '수원fc',
#   'content': '너무 재미있었고 다음에 또 가고싶네요!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 수원fc 너무 재미있었고 다음에 또 가고싶네요!'},
#  {'title': '담엔 좀 이겨보아여',
#   'content': '4전 4패 기록하구\n터덜터덜 관람했습니다. \n담 직관엔 꼭 승리할 수 있길 바라보아요.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠
^',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 재인폭포카라반 아들군대 수료식으로 예약했어요~\n저렴한금액으로 완전 쾌적하고 편안하게 잘 쓰고왔습니다친구들과 함께 상의해서 또 와야겠어요^^'},
#  {'title': '좋아요',
#   'content': '재밌어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 좋아요 재밌어요'},
#  {'title': '지지대더비',
#   'content': '이겨서 다행입니다.\n우리 승격할 수 있습니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 지지대더비 이겨서 다행입니다.\n우리 승격할 수 있습니다.'},
#  {'title': '여름엔 시간 구애 받지 않는 피크닉장 으로',
#   'content': '다좋은데 여름에 더워서 오후늦게가서 고기만 구워먹고옴',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 여름엔 시간 구애 받지 않는 피크닉장 으로 다좋은데 여름에 더워서 오후늦게가서 고기만 구워먹고옴'},
#  {'title': '두산vs키움 잠실경기 재밌게 봤습니다',
#   'content': '이겨서 더 좋으네요 ㅎㅎㅎ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 두산vs키움 잠실경기 재밌게 봤습니다 이겨서 더 좋으네요 ㅎㅎㅎ'},
#  {'title': '좋았어요',
#   'content': '광동 오랜만에 승리! 짱~',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 좋았어요 광동 오랜만에 승리! 짱~'},
#  {'title': '존잼',
#   'content': '내가 여태 직관으로 봤던 야구중에 제일 재미있었음! 홈런 처음봤음! 무려 홈런치기 어렵다는 잠실구장에서!!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 존잼 내가 여태 직관으로 봤던 야구중에 제일 재미있었음! 홈런 처음봤음! 무려 홈런치기 어렵다는 잠실구장에서!!'},
#  {'title': '관리형평성 어긋남 잡초제거 안됨',
#   'content': '초창기와 다르게 잔듸환경과 잡초 풀 제거가 미흡\n주차관리가 형평성에 어긋납니다. 제일 끝자리 통행등 지장이 없는 위치인데도 사이트안에 넣으라고 10분도 되지않아 제차 전화해서 엄청나게 엄격히 굴더니 카라반 이용자가 그자리에 차를대고 밤을세도 관리하지않는건 이해되지않음',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 관리형평성 어긋남 잡초제거 안됨 초창기와 다르게 잔듸환경과 잡초 풀 제거가 미흡\n주차관리가 형평성에 어긋납니다. 제일 끝자리 통행등 지장이 없는 위치인데도 사이트안에 넣으라고 10분도 되지않아 제차 전화해서 엄청나게 엄격히 굴더니 카라반 이용자가 그자리에 차를대고 밤을세도 관리하지않는건 이해되지않음'},
#  {'title': '캠핑장~',
#   'content': '텐트치고 숯불에 바베큐도 먹고 수영도 하고 너무 행복한 캠핑이였어요. 강추입니다.~^^',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 캠핑장~ 텐트치고 숯불에 바베큐도 먹고 수영도 하고 너무 행복한 캠핑이였어요. 강추입니다.~^^'},
#  {'title': '다음에도 또 올려구요',
#   'content': '완전 재밌게 잘보았습니다. 예매는 어려웠지만 보람찬 하루였습니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 다음에도 또 올려구요 완전 재밌게 잘보았습니다. 예매는 어려웠지만 보람찬 하루였습니다.'},
#  {'title': '좋은 경기이었어요.',
#   'content': '좋은 경험이었다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 좋은 경기이었어요. 좋은 경험이었다.'},
#  {'title': '구장관리 엉망',
#   'content': '전국에서 제일 비싼입장료를 징수하면서\n\n전담 구장 관리인도 없어 \n잔디는 무성하게 키워서\n공이 굴러가지도 않고 \n\n그린주변은 정리가 \n않되어 울퉁불퉁 도대체 \n서부사업소 담당자들은 뭘하는건지?\n\n별 1점주기도 아까움',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 구장관리 엉망 전국에서 제일 비싼입장료를 징수하면서\n\n전담 구장 관리인도 없어 \n잔디는 무성하게 키워서\n공이 굴러가지도 않고 \n\n그린주변은 정리가 \n않되어 울퉁불퉁 도대체 \n서부사업소 담당자들은 뭘하는건지?\n\n별 1점주기도 아까움'},
#  {'title': '최고의 경기',
#   'content': 'SSG가 리드했던 경기였다다음에도 또 보러올것이다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최고의 경기 SSG가 리드했던 경기였다다음에도 또 보러올것이다'},
#  {'title': '졌어도 위닝이자나 ~',
#   'content': '우리가 더 안 더운 날 졌잖아? 완전 럭키 두산이자나~',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 졌어도 위닝이자나 ~ 우리가 더 안 더운 날 졌잖아? 완전 럭키 두산이자나~'},
#  {'title': '미르스타다움',
#   'content': '트랙이 있는 구장이라 시야가 걱정 되었는데 최근에 건립된 구장이라 관람이 매우 좋았습니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 미르스타다움 트랙이 있는 구장이라 시야가 걱정 되었는데 최근에 건립된 구장이라 관람이 매우 좋았습니다.'},
#  {'title': '경기는 졌지만',
#   'content': '잘봤습니다\n에어컨 좋아요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 경기는 졌지만 잘봤습니다\n에어컨 좋아요'},
#  {'title': '두산베어스! 승리를 위하여...',
#   'content': '뜨거운 열기에도 두산 응원 열정은 식지 않네요..\n너무너무 더워서 쓰러질뻔했지만 즐겁게 보고왔습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 두산베어스! 승리를 위하여... 뜨거운 열기에도 두산 응원 열정은 식지 않네요..\n너무너무 더워서 쓰러질뻔했지만 즐겁게 보고왔습니다'},
#  {'title': '고척 ssg vs 키움',
#   'content': '너무 재밌었어요 열심히응원해서 목청도 터지고\n아주 레전드였습니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 고척 ssg vs 키움 너무 재밌었어요 열심히응원해서 목청도 터지고\n아주 레전드였습니다.'},
#  {'title': '가족들과 잘 놀다 갑니다.',
#   'content': '1학년 둘째아이가 너무 좋아했어요. 초등 고학년보다는 저학년이나 유아들이 좋아할만한 물놀이터입니다. 그래도 데크에 텐트도 치고 음식도 먹고 즐겁게 놀다 갑니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 가족들과 잘 놀다 갑니다. 1학년 둘째아이가 너무 좋아했어요. 초등 고학년보다는 저학년이나 유아들이 좋아할만한 물놀이터입니다. 그래도 데크에 텐트도 치고 음식도 먹고 즐겁게 놀다 갑니다.'},
#  {'title': '친절하고 사원한 캐라반',
#   'content': '2인실이라 살짝 좁았지만 깨끗이 잘 관리되어 있었습니다. 다만 야왼 모기가 장난 아니예요 ㅎ',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 친절하고 사원한 캐라반 2인실이라 살짝 좁았지만 깨끗이 잘 관리되어 있었습니다. 다만 야왼 모기가 장난 아니예요 ㅎ'},
#  {'title': '챔피언스',
#   'content': '너무 좋았습니다 현장감이 엄청납니다 다들 한번씩 가보세요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 챔피언스 너무 좋았습니다 현장감이 엄청납니다 다들 한번씩 가보세요'},
#  {'title': '챔피언스',
#   'content': '너무 좋았습니다 현장감이 엄청납니다 다들 한번씩 가보세요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 챔피언스 너무 좋았습니다 현장감이 엄청납니다 다들 한번씩 가보세요'},
#  {'title': 'LG트윈스 경기!',
#   'content': '배재준 선수와 안익훈 선수 가까이에서 볼 수 있어서 너무 좋음!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠
니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 키움 고척 홈경기 여름에도 시원하게 야구경기를 관람할 수 있어서 가족 모두 너무 좋았습니다'},
#  {'title': '대한민국 화이팅',
#   'content': '두팀모두 패했지만 고생많으셨습니다.\n누구보다 속상하고  아쉽겠지만 앞으로 더 힘내세용. 홧팅??',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 대한민국 화이팅 두팀모두 패했지만 고생많으셨습니다.\n누구보다 속상하고  아쉽겠지만 앞으로 더 힘내세용. 홧팅??'},
#  {'title': 'NC vs. 키움',
#   'content': '오랜만에 NC의 완벽한 승리!! NC 에이스의 무서운 저력을 느낀 경기였음',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 NC vs. 키움 오랜만에 NC의 완벽한 승리!! NC 에이스의 무서운 저력을 느낀 경기였음'},
#  {'title': '올해 마지막 경기',
#   'content': '였네요.\n수원 축구, 그리울 겁니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 올해 마지막 경기 였네요.\n수원 축구, 그리울 겁니다.'},
#  {'title': '너무 즐거운 관람이었습니다',
#   'content': '외야 4층도 경기 잘 보이고 돔구장이라 쾌적합니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 너무 즐거운 관람이었습니다 외야 4층도 경기 잘 보이고 돔구장이라 쾌적합니다'},
#  {'title': '최악의 캠핑',
#   'content': '편의점 직원은 볼때마다 기분이 안좋아보이시고,\n많이 갓지만 볼때마다불편\n\n방역도 안하는지 모기를 한30방 물렸네요\n\n지난주까지 크록스신고 들어 가던  수영장은\n워터슈즈없음 못들어간다고 저지당하는 상황에\n\n입구에서 워터슈즈25,000에 파는 상술에 경악을 금치못함...\n\n2박 결제 하고 1박하고 기분나빠서 나왔네요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 최악의 캠핑 편의점 직원은 볼때마다 기분이 안좋아보이시고,\n많이 갓지만 볼때마다불편\n\n방역도 안하는지 모기를 한30방 물렸네요\n\n지난주까지 크록스신고 들어 가던  수영장은\n워터슈즈없음 못들어간다고 저지당하는 상황에\n\n입구에서 워터슈즈25,000에 파는 상술에 경악을 금치못함...\n\n2박 결제 하고 1박하고 기분나빠서 나왔네요'},
#  {'title': '정말 신납니다!',
#   'content': '두산 화이팅!!서울의 주인은 누구다?바로, 두 to the 산!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 정말 신납니다! 두산 화이팅!!서울의 주인은 누구다?바로, 두 to the 산!'},
#  {'title': '아쉽지만 재미있는 경기',
#   'content': 'LG가 초반에 5실점 하면서 자칫 지루한 경기로 흘러가지 않나 싶었지만 6:7까지 따라가면서 흥미진진했던 경기였습니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 아쉽지만 재미있는 경기 LG가 초반에 5실점 하면서 자칫 지루한 경기로 흘러가지 않나 싶었지만 6:7까지 따라가면서 흥미진진했던 경기였습니다.'},
#  {'title': '유익한 시간이었습니다.',
#   'content': '인터파크티켓으로 예약해서 \n좋은 추억 쌓고 있습니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 유익한 시간이었습니다. 인터파크티켓으로 예약해서 \n좋은 추억 쌓고 있습니다.'},
#  {'title': '고척 최고',
#   'content': '고척돔에서 야구를 보니 시원하고 외야인데도 시야가 좋았어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 고척 최고 고척돔에서 야구를 보니 시원하고 외야인데도 시야가 좋았어요'},
#  {'title': '시원하니 좋아요..',
#   'content': '깨끗하고,시원하니 좋았으나, 전에 비치되었던 것만 기억하고 수건, 모기향이 없어 조금 아쉬웠네요ㅎ그거 말고는 퍼펙트였어요..준비 철저히 하고가려구요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠
니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 Lck 재밌어요 직원분들 친절하고 재밌게 봤습니다'},
#  {'title': '수원경기는 역시 직관이',
#   'content': '최고 입니다! 그들의 응원열기 국내 원탑',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 수원경기는 역시 직관이 최고 입니다! 그들의 응원열기 국내 원탑'},
#  {'title': '실제는 다른 챔스..',
#   'content': '맨날 유튜브에서만 보니까 좀 멋있네. 이정도 였는데 실제로 가서 보니까 너무 웅장하고 간지작살이라 안가고싶을 수가 없네요.. 바로 친구한테 가보라고 후회안한다고 말했어요. 굳굳',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 실제는 다른 챔스.. 맨날 유튜브에서만 보니까 좀 멋있네. 이정도 였는데 실제로 가서 보니까 너무 웅장하고 간지작살이라 안가고싶을 수가 없네요.. 바로 친구한테 가보라고 후회안한다고 말했어요. 굳굳'},
#  {'title': '오랜만에 관람',
#   'content': '인터파크로 간편한 예매 좋아요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 오랜만에 관람 인터파크로 간편한 예매 좋아요'},
#  {'title': '짜릿한 경기였다..!',
#   'content': '잠실에서 무더웠던 날씨에도 지치않을 수 있었던 건 히어로즈의 더 뜨거웠던 집중력 덕분이었습니다!\n끝까지 해내는 히어로즈 잠실에서 응원할 수있어 행복했고 더위에 지치지 않고 더 건강하게 야구할 수 있기를 늘 응원합니다!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 짜릿한 경기였다..! 잠실에서 무더웠던 날씨에도 지치않을 수 있었던 건 히어로즈의 더 뜨거웠던 집중력 덕분이었습니다!\n끝까지 해내는 히어로즈 잠실에서 응원할 수있어 행복했고 더위에 지치지 않고 더 건강하게 야구할 수 있기를 늘 응원합니다!'},
#  {'title': '자리의 중요성',
#   'content': '자리가 좋아서 안 보이는 부분까지 잘 보고 왔어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 자리의 중요성 자리가 좋아서 안 보이는 부분까지 잘 보고 왔어요'},
#  {'title': '미르 첫 경기 좋았습니다.',
#   'content': '미르 첫경기 주차난에 너무 더웠지만 이겨서 너무 행복했습니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 미르 첫 경기 좋았습니다. 미르 첫경기 주차난에 너무 더웠지만 이겨서 너무 행복했습니다.'},
#  {'title': '행복한 시간',
#   'content': '마음 깊이 따듯해지는 시간이었습니다',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 행복한 시간 마음 깊이 따듯해지는 시간이었습니다'},
#  {'title': '재미있게 봤어요~',
#   'content': '기대이상 재미있어요^^',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 재미있게 봤어요~ 기대이상 재미있어요^^'},
#  {'title': '키움 엔시전 관람',
#   'content': '고척돔은 매우 시원했고 경기는 인생에 남을만한 대역전 레전드경기였네요 다음에 무조건 또 관람입니다~',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 키움 엔시전 관람 고척돔은 매우 시원했고 경기는 인생에 남을만한 대역전 레전드경기였네요 다음에 무조건 또 관람입니다~'},
#  {'title': '좋아요',
#   'content': '좋아요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 좋아요 좋아요'},
#  {'title': '야구 관람 후기',
#   'content': '두산이 이겨서 너무 좋았어요',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 야구 관람 후기 두산이 이겨서 너무 좋았어요'},
#  {'title': '상당히 만족스런 LCK관람',
#   'content': '관계자 스텝분들이 질서정연하게 안내해주셨고 관람석은 정말 깨끗했습니다. 관람하는내내 불편함 하나없이 재밌게 즐겼습니다. 기회가 된다면 또 가고싶어요! 감사합니다.',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠

#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 처음 다녀온 킨텍스 캠핑장 예약하기 하늘에 별따기만큼 어렵게 성공해서 주말에 드디어 다녀왔는데, 좋긴 좋네요~ㅎㅎ\n나름 조용하고 시설들이 깔끔하게 되어있어서 행복한 시간 만들고 왔습니다. 원하는 날짜에 예약하기는 어렵지만 또다시 도전해서 갈 예정입니다.'},
#  {'title': '너무 좋아요',
#   'content': '1루 자리가 자리가 좁기는 하지만그늘도 있고 시야도 넓게 잘 보여서 너무 좋아요!!',
#   'category': 4,
#   'category_name': '스포츠',
#   'all_text': '스포츠 너무 좋아요 1루 자리가 자리가 좁기는 하지만그늘도 있고 시야도 넓게 잘 보여서 너무 좋아요!!'},
#  {'title': '파트원들과 함께한 야구장',
# ...
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 여러 면에서 시리즈의 한계를 보여준다. <보스 베이비>를 참고한 듯한 서사는 새롭지 않으며, 메가 미니언즈의 캐릭터 디자인은 빌런을 보는 것 같았다.'},
#  {'title': '슈퍼배드 4',
#   'content': '귀여운데, 유치함...',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 귀여운데, 유치함...'},
#  {'title': '슈퍼배드 4',
#   'content': '더이상 매력없는 캐릭터에 너무 부실한 각본.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 더이상 매력없는 캐릭터에 너무 부실한 각본.'},
#  {'title': '슈퍼배드 4',
#   'content': '미니언들 비중이 적고 아빠로서 그루의 매력은 떨어진다.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 미니언들 비중이 적고 아빠로서 그루의 매력은 떨어진다.'},
#  {'title': '슈퍼배드 4',
#   'content': '뼈에서 더 이상 우러나올 골수도 남아 있지 않았으나 이만하면 선방한 듯하다. 이제는 진짜 끝임을 인정하고 퇴장할 때.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 뼈에서 더 이상 우러나올 골수도 남아 있지 않았으나 이만하면 선방한 듯하다. 이제는 진짜 끝임을 인정하고 퇴장할 때.'},
#  {'title': '슈퍼배드 4',
#   'content': '유치하게 잘 만든 영화',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 유치하게 잘 만든 영화'},
#  {'title': '슈퍼배드 4',
#   'content': '3편보다는 나은데, 1-2편에는 미치지 못하는 느낌이었다. 악당의 서사가 생각보다 좀 부실하고, 전개자체가 뻔하다보니...오히려 신캐릭 파피를 조금 더 부각하는게 낫지 않았을까싶다',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 3편보다는 나은데, 1-2편에는 미치지 못하는 느낌이었다. 악당의 서사가 생각보다 좀 부실하고, 전개자체가 뻔하다보니...오히려 신캐릭 파피를 조금 더 부각하는게 낫지 않았을까싶다'},
#  {'title': '슈퍼배드 4',
#   'content': '미니언이 넘 사랑스러움💞',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 미니언이 넘 사랑스러움💞'},
#  {'title': '슈퍼배드 4',
#   'content': '메가 미니언 너무 웃겼다 미니언만의 엉뚱매력은 정말 ㅋㅋ',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 메가 미니언 너무 웃겼다 미니언만의 엉뚱매력은 정말 ㅋㅋ'},
#  {'title': '슈퍼배드 4',
#   'content': '여전히 귀여운 미니언즈들. 그리고 아이들. 근데 왜 마블처럼 미니언즈를 이상하게 변종을 만들고 그러는지….',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 여전히 귀여운 미니언즈들. 그리고 아이들. 근데 왜 마블처럼 미니언즈를 이상하게 변종을 만들고 그러는지….'},
#  {'title': '범죄도시4',
#   'content': 'No Funny\nNo Develop\nNo Action\n“카레에서 짜장으로 바뀌면 뭐하나 이미 아는 맛인데.”',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 No Funny\nNo Develop\nNo Action\n“카레에서 짜장으로 바뀌면 뭐하나 이미 아는 맛인데.”'},
#  {'title': '범죄도시4',
#   'content': '신기하게 같은 느낌인데 새롭다 다만 너무 초심만 지키는 느낌 슬슬 흥미를 잃을지도……….',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 신기하게 같은 느낌인데 새롭다 다만 너무 초심만 지키는 느낌 슬슬 흥미를 잃을지도……….'},
#  {'title': '범죄도시4',
#   'content': '차라리 김무열 단독 빌런을 하지 그랬어',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 차라리 김무열 단독 빌런을 하지 그랬어'},
#  {'title': '범죄도시4',
#   'content': '범도가 나랑은 맞지않는구나만 다시금 깨닫고온',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 범도가 나랑은 맞지않는구나만 다시금 깨닫고온'},
#  {'title': '범죄도시4',
#   'content': '이제그만 범죄도시 보내주자 갈수록 노잼이다~ 1편은 정말\n최고 였고 대작이였다~',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 이제그만 범죄도시 보내주자 갈수록 노잼이다~ 1편은 정말\n최고 였고 대작이였다~'},
#  {'title': '범죄도시4',
#   'content': '범도 시리즈는 이 미친남성들이 너덜너덜하게 털리는 모습을 볼 수 있는 영화 시리즈라고 생각합니다',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 범도 시리즈는 이 미친남성들이 너덜너덜하게 털리는 모습을 볼 수 있는 영화 시리즈라고 생각합니다'},
#  {'title': '범죄도시4',
#   'content': '뭐...무슨 맛인지 아시죠?',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 뭐...무슨 맛인지 아시죠?'},
#  {'title': '범죄도시4',
#   'content': '세번은 안당하지 라고 생각했던 한달전으로 돌아가고싶다.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 세번은 안당하지 라고 생각했던 한달전으로 돌아가고싶다.'},
#  {'title': '범죄도시4',
#   'content': '시사회 찐 관람 후기',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 시사회 찐 관람 후기'},
#  {'title': '범죄도시4',
#   'content': '마동석 범죄도시3에서는 마이크 타이슨 같은 느낌이였는데 범죄도시4에서는 조지 포먼 같은 느낌이 나서 시리즈 마다 다른 복싱 기술 구사하는 마동석 보는 재미가 있음.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 마동석 범죄도시3에서는 마이크 타이슨 같은 느낌이였는데 범죄도시4에서는 조지 포먼 같은 느낌이 나서 시리즈 마다 다른 복싱 기술 구사하는 마동석 보는 재미가 있음.'},
#  {'title': '범죄도시4',
#   'content': '기대보다 더 찐한 액션! 섹쉬한 빌런 김무열! 마동석은 마동석했고, 장이수는 장이수했다.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 기대보다 더 찐한 액션! 섹쉬한 빌런 김무열! 마동석은 마동석했고, 장이수는 장이수했다.'},
#  {'title': '범죄도시4',
#   'content': '재밌다!! 3편에서 실망을 했기 때문에 더 이를 간듯한 코믹액션!!',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 재밌다!! 3편에서 실망을 했기 때문에 더 이를 간듯한 코믹액션!!'},
#  {'title': '범죄도시4',
#   'content': "분노의 질주와 같이 그 '시리즈'이기에 볼 가치가 있는 영화",
#   'category': 1,
#   'category_name': '영화',
#   'all_text': "영화 범죄도시4 분노의 질주와 같이 그 '시리즈'이기에 볼 가치가 있는 영화"},
#  {'title': '범죄도시4',
#   'content': '3보다 낫겠지?, 황야에서 감독과 마동석 조합이 기대를 충분히 낮춰서인지 적당히 즐기기에 이정도만한 영화가 있나 싶다. 이런 한국영화의 시장상황은 차치하더라도..',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 3보다 낫겠지?, 황야에서 감독과 마동석 조합이 기대를 충분히 낮춰서인지 적당히 즐기기에 이정도만한 영화가 있나 싶다. 이런 한국영화의 시장상황은 차치하더라도..'},
#  {'title': '범죄도시4',
#   'content': '역시 기대하는 웃음과 시원한 사이다를 안겨줌. 게다가 이번에는 액션이 진짜 너무 좋아서, 시리즈 중에 제일 좋았음!',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 역시 기대하는 웃음과 시원한 사이다를 안겨줌. 게다가 이번에는 액션이 진짜 너무 좋아서, 시리즈 중에 제일 좋았음!'},
#  {'title': '범죄도시4',
#   'content': '기대를 저버리지 않는 시리즈물! 슬슬 더워지는데 시원한 한방! 강력해진 빌런! 돌아온 장이수까지! 아는 맛이지만 아는 맛이 무섭지',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 기대를 저버리지 않는 시리즈물! 슬슬 더워지는데 시원한 한방! 강력해진 빌런! 돌아온 장이수까지! 아는 맛이지만 아는 맛이 무섭지'},
#  {'title': '범죄도시4',
#   'content': '시사회로 보길 잘했다. \n다른 시리즈물들과는 확연히 다르게 점점 진화하는 깊은맛.\n최고의 프랜차이즈!',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 시사회로 보길 잘했다. \n다른 시리즈물들과는 확연히 다르게 점점 진화하는 깊은맛.\n최고의 프랜차이즈!'},
#  {'title': '범죄도시4',
#   'content': '4/15(월) 코엑스 시사회 관람.\n일단 첫소감은 와 이걸 또 해내네? 솔직히 4번째니까 기대 안했는데 괜한 걱정이었네요. 개봉하고 나면 한번 더 볼 예정(4D 괜찮을까요?)',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 4/15(월) 코엑스 시사회 관람.\n일단 첫소감은 와 이걸 또 해내네? 솔직히 4번째니까 기대 안했는데 괜한 걱정이었네요. 개봉하고 나면 한번 더 볼 예정(4D 괜찮을까요?)'},
#  {'title': '범죄도시4',
#   'content': "어제 시사회 다녀왔습니다\n이번에도 범죄도시 특유의 사이다 액션과 유머코드를 시원하게 즐기다 보니 어느새 엔딩 크레딧...\n미국에 '존윅'이 있다면, 한국은 범죄도시죠!",
#   'category': 1,
#   'category_name': '영화',
#   'all_text': "영화 범죄도시4 어제 시사회 다녀왔습니다\n이번에도 범죄도시 특유의 사이다 액션과 유머코드를 시원하게 즐기다 보니 어느새 엔딩 크레딧...\n미국에 '존윅'이 있다면, 한국은 범죄도시죠!"},
#  {'title': '범죄도시4',
#   'content': '범죄도시에게 특유의 묵직하고 타격감 넘치는 액션씬이 만족스러움.\n범죄도시4 안보면 볼 영화 없다!',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 범죄도시에게 특유의 묵직하고 타격감 넘치는 액션씬이 만족스러움.\n범죄도시4 안보면 볼 영화 없다!'},
#  {'title': '범죄도시4',
#   'content': '업그레이드된 서사, 돌아온 장이수',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 업그레이드된 서사, 돌아온 장이수'},
#  {'title': '범죄도시4',
#   'content': '시리즈 최고의 재미였습니다.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 시리즈 최고의 재미였습니다.'},
#  {'title': '범죄도시4',
#   'content': '범죄도시 시리즈가 계속 나옴으로써 우려가 되고 또 재밌을까 하는 고민이 있지만 그런 고민을 깨고 지금까지도 재밌네요. 시리즈가 나올수록 완성도 또한 더 좋아지는 거 같아요 추천!!',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 범죄도시 시리즈가 계속 나옴으로써 우려가 되고 또 재밌을까 하는 고민이 있지만 그런 고민을 깨고 지금까지도 재밌네요. 시리즈가 나올수록 완성도 또한 더 좋아지는 거 같아요 추천!!'},
#  {'title': '범죄도시4',
#   'content': '시사회를  통해 봤습니다  \n강력한 마석도와 살인병기 백창기의 대결\n돌아온 장이수의 코믹함 얄미운 장동철의 연기가 돋보입니다 역대급 재밌습니다!!',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 시사회를  통해 봤습니다  \n강력한 마석도와 살인병기 백창기의 대결\n돌아온 장이수의 코믹함 얄미운 장동철의 연기가 돋보입니다 역대급 재밌습니다!!'},
#  {'title': '범죄도시4',
#   'content': '매번 비슷한 이야기로 작품이 전개되는데도, 계속 재밌을 수 있다니...언제까지 이럴 수 있나보자. 8편까지 나온다고?',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 매번 비슷한 이야기로 작품이 전개되는데도, 계속 재밌을 수 있다니...언제까지 이럴 수 있나보자. 8편까지 나온다고?'},
#  {'title': '범죄도시4',
#   'content': '현실을 기반한 매력 그 나머지는 공산품',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 현실을 기반한 매력 그 나머지는 공산품'},
#  {'title': '범죄도시4',
#   'content': '아직까진 맛있는 사골국',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 아직까진 맛있는 사골국'},
#  {'title': '범죄도시4',
#   'content': '블라인드 시사회로 봤어요. 4편도 기대하셔도 됩니다~! (아직 출시까지 일년정도 남아서 스포는 못해드려요)',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 블라인드 시사회로 봤어요. 4편도 기대하셔도 됩니다~! (아직 출시까지 일년정도 남아서 스포는 못해드려요)'},
#  {'title': '범죄도시4',
#   'content': '이제는 맛없는 아는 맛',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 이제는 맛없는 아는 맛'},
#  {'title': '범죄도시4',
#   'content': '우리의 FDA! 장이수가 다 했다.\n개인적으로 2,3편의 빌런보다 훨 인상적이었던 4편의 빌런.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 우리의 FDA! 장이수가 다 했다.\n개인적으로 2,3편의 빌런보다 훨 인상적이었던 4편의 빌런.'},
#  {'title': '범죄도시4',
#   'content': '1.2가 그립다 더는 볼 수 없는 걸까?',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 1.2가 그립다 더는 볼 수 없는 걸까?'},
#  {'title': '범죄도시4',
#   'content': '액션에 더 신경을 쓴 부분이 만족스러웠음\n악을 응징하는데서 오는 카타르시스란..\n다 아는 맛이지만 여전히 맛있음',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 액션에 더 신경을 쓴 부분이 만족스러웠음\n악을 응징하는데서 오는 카타르시스란..\n다 아는 맛이지만 여전히 맛있음'},
#  {'title': '범죄도시4',
#   'content': '김무열 섹시해',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 김무열 섹시해'},
#  {'title': '범죄도시4',
#   'content': '더 롱런하려면 변화가 필요한 시리즈이긴 하다.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 더 롱런하려면 변화가 필요한 시리즈이긴 하다.'},
#  {'title': '범죄도시4',
#   'content': '8월 9일 블라인드 미완성본 시사회를 통해 관람.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 8월 9일 블라인드 미완성본 시사회를 통해 관람.'},
#  {'title': '범죄도시4',
#   'content': '범죄도시가 ‘범죄도시‘했다.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 범죄도시가 ‘범죄도시‘했다.'},
#  {'title': '범죄도시4',
#   'content': '지금까지 나온 시즌중엔 제일 아쉬웠다 급하게 작업하고 빠르게 편집하다보니 놓친게 많은 것 같은 느낌 그리고 자꾸만 웃기려고 노리고 치는 듯한 대사에 웃음을 잃게 된..',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 지금까지 나온 시즌중엔 제일 아쉬웠다 급하게 작업하고 빠르게 편집하다보니 놓친게 많은 것 같은 느낌 그리고 자꾸만 웃기려고 노리고 치는 듯한 대사에 웃음을 잃게 된..'},
#  {'title': '범죄도시4',
#   'content': '갈수록 부실해지는 데는 이유가 있지 않을까',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 갈수록 부실해지는 데는 이유가 있지 않을까'},
#  {'title': '범죄도시4',
#   'content': '빌런이 너무 섹시하잖아 초반 복근에 시선강탈😍 마석도, 장이수 콤비 웃음지뢰. 범도4에서도 역시나 주옥같은 명대사들 쏟아짐.  천만 무난히 돌파하겠어요👏👏👏',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 빌런이 너무 섹시하잖아 초반 복근에 시선강탈😍 마석도, 장이수 콤비 웃음지뢰. 범도4에서도 역시나 주옥같은 명대사들 쏟아짐.  천만 무난히 돌파하겠어요👏👏👏'},
#  {'title': '범죄도시4',
#   'content': '그냥 볼만한 액션물이 되어버렸다.....',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 그냥 볼만한 액션물이 되어버렸다.....'},
#  {'title': '범죄도시4',
#   'content': '범죄도시1,2편 재밌다고 하는 사람들 많았는데 나는 3편이 제일 재밌었고 (가족들과 다같이 보기 좋았음) 4편에서 느낀게 액션, 연출, 유머 놓친게 없었음.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 범죄도시1,2편 재밌다고 하는 사람들 많았는데 나는 3편이 제일 재밌었고 (가족들과 다같이 보기 좋았음) 4편에서 느낀게 액션, 연출, 유머 놓친게 없었음.'},
#  {'title': '범죄도시4',
#   'content': '3도 진짜 재밌어서 박장대소 하면서 봤는데 4 시사회때보고 뒤집어 졌다. 또 보러가야지! 범죄도시 4 화이팅',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 3도 진짜 재밌어서 박장대소 하면서 봤는데 4 시사회때보고 뒤집어 졌다. 또 보러가야지! 범죄도시 4 화이팅'},
#  {'title': '범죄도시4',
#   'content': '3편보다 액션이나 빌런 매력은 뛰어나지만 스토리가 너무 늘어지는 느낌이들고 필요 없는 인물이 많은것 같다',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 3편보다 액션이나 빌런 매력은 뛰어나지만 스토리가 너무 늘어지는 느낌이들고 필요 없는 인물이 많은것 같다'},
#  {'title': '범죄도시4',
#   'content': '어제 시사회로 보고왔는데 역시 잘끓인 김치찌개는 최고다.. 또 생각나네 먹고 싶어서',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 어제 시사회로 보고왔는데 역시 잘끓인 김치찌개는 최고다.. 또 생각나네 먹고 싶어서'},
#  {'title': '범죄도시4',
#   'content': '범도3보다는 재밌다!',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 범도3보다는 재밌다!'},
#  {'title': '범죄도시4',
#   'content': "주제가 사이버 범죄라지만, 결국은 '피도 좀 흘리는' 마동석 미사일 주먹에 승부를 봐야하는 건 어쩔 수 없는 것으로.",
#   'category': 1,
#   'category_name': '영화',
#   'all_text': "영화 범죄도시4 주제가 사이버 범죄라지만, 결국은 '피도 좀 흘리는' 마동석 미사일 주먹에 승부를 봐야하는 건 어쩔 수 없는 것으로."},
#  {'title': '범죄도시4',
#   'content': '시리즈가 상하기전까진 4점. 아직 유통기한남아있다',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 시리즈가 상하기전까진 4점. 아직 유통기한남아있다'},
#  {'title': '범죄도시4',
#   'content': '마동석표 액션 언제봐도 통쾌하고 재밌었습니다! 김무열배우님은 조금더 잔인하게 나왔으면하는 아쉬움이 있습니다. 박지환 배우님은 진짜 거의 범죄도시4의 주인공이였습니다👍',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 범죄도시4 마동석표 액션 언제봐도 통쾌하고 재밌었습니다! 김무열배우님은 조금더 잔인하게 나왔으면하는 아쉬움이 있습니다. 박지환 배우님은 진짜 거의 범죄도시4의 주인공이였습니다👍'},
#  {'title': '슈퍼배드 4',
#   'content': '◈ 이제, 점점… 미니언들의 귀여움 파워도 힘에 부치는 느낌이다.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 ◈ 이제, 점점… 미니언들의 귀여움 파워도 힘에 부치는 느낌이다.'},
#  {'title': '슈퍼배드 4',
#   'content': '개구진 미니언즈와 함께 웃고 가족의 사랑이 무엇인가 생각해보게 하는 따뜻한 이야기',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 개구진 미니언즈와 함께 웃고 가족의 사랑이 무엇인가 생각해보게 하는 따뜻한 이야기'},
#  {'title': '슈퍼배드 4',
#   'content': '익숙한 내용 그러나 이제는 신선함은 사라졌다',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 익숙한 내용 그러나 이제는 신선함은 사라졌다'},
#  {'title': '슈퍼배드 4',
#   'content': '이게 <미니언즈 3>인지 <슈퍼배드 4>인지... 이 둘을 확실하게 나눌 수 있게 분간을 시켜줬으면.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 슈퍼배드 4 이게 <미니언즈 3>인지 <슈퍼배드 4>인지... 이 둘을 확실하게 나눌 수 있게 분간을 시켜줬으면.'},
#  {'title': '인사이드 아웃 2',
#   'content': '잠시 스쳐가는 불안에, 여러 감정들의 공존으로 끝을 이룬다',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 잠시 스쳐가는 불안에, 여러 감정들의 공존으로 끝을 이룬다'},
#  {'title': '인사이드 아웃 2',
#   'content': '감정애 대해 한번 더 생각해보개 된.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 감정애 대해 한번 더 생각해보개 된.'},
#  {'title': '인사이드 아웃 2',
#   'content': '다 컸는데도 내 불안이는 아직도 열일 중이네, 좀 말려봐',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 다 컸는데도 내 불안이는 아직도 열일 중이네, 좀 말려봐'},
#  {'title': '인사이드 아웃 2',
#   'content': '기대를 많이 해서 그런지 딱히 재밌진 않았음',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 기대를 많이 해서 그런지 딱히 재밌진 않았음'},
#  {'title': '인사이드 아웃 2',
#   'content': '어느새 슬픔이와 버럭이, 까칠이, 불안이가 가득한 어른이 되어버렸지만 내 안에 기쁨이가 더 일할 수 있게 더 노력해볼게',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 어느새 슬픔이와 버럭이, 까칠이, 불안이가 가득한 어른이 되어버렸지만 내 안에 기쁨이가 더 일할 수 있게 더 노력해볼게'},
#  {'title': '인사이드 아웃 2',
#   'content': "결국 픽사 작품의 핵심 중 하나는 '공감'이다. 그리고 이 시리즈는 그것을 가장 창의적으로 활용한다.",
#   'category': 1,
#   'category_name': '영화',
#   'all_text': "영화 인사이드 아웃 2 결국 픽사 작품의 핵심 중 하나는 '공감'이다. 그리고 이 시리즈는 그것을 가장 창의적으로 활용한다."},
#  {'title': '인사이드 아웃 2',
#   'content': '행복한 모습도, 슬픈 표정도, 당황한 얼굴도, 불안한 나도 흡잡을데 없이 모두 나였다.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 행복한 모습도, 슬픈 표정도, 당황한 얼굴도, 불안한 나도 흡잡을데 없이 모두 나였다.'},
#  {'title': '인사이드 아웃 2',
#   'content': '어른들한테도 한번더 생각해보는 작품',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 어른들한테도 한번더 생각해보는 작품'},
#  {'title': '인사이드 아웃 2',
#   'content': '더욱 복잡해진 라일리의 자아만큼이나 입체적이게 된 감정들에 대한 묘사가 아주 매력적, 다만 사춘기라는 인생의 분기점이 될 수 있는 이벤트를 사건 하나로만 다룬다는 것이 아쉬웠음.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 더욱 복잡해진 라일리의 자아만큼이나 입체적이게 된 감정들에 대한 묘사가 아주 매력적, 다만 사춘기라는 인생의 분기점이 될 수 있는 이벤트를 사건 하나로만 다룬다는 것이 아쉬웠음.'},
#  {'title': '인사이드 아웃 2',
#   'content': '청소년때의 사춘기 시절을 생각 해 볼 수 있는 시간이였다',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 청소년때의 사춘기 시절을 생각 해 볼 수 있는 시간이였다'},
#  {'title': '인사이드 아웃 2',
#   'content': '알록달록한 감정들의 불협화음 그러나 마지막은 나일리를 위해 앙상블',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 알록달록한 감정들의 불협화음 그러나 마지막은 나일리를 위해 앙상블'},
#  {'title': '인사이드 아웃 2',
#   'content': '살다 보면 꼭 겪는 내면의 성장',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 살다 보면 꼭 겪는 내면의 성장'},
#  {'title': '인사이드 아웃 2',
#   'content': '버럭이 귀여워 죽겠네 진짜',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 버럭이 귀여워 죽겠네 진짜'},
#  {'title': '인사이드 아웃 2',
#   'content': '미래에 대한 생각이 늘어나며 추가되는 감정들',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 미래에 대한 생각이 늘어나며 추가되는 감정들'},
#  {'title': '인사이드 아웃 2',
#   'content': '자야 형성에 필요한 여러 추억들과 경험들이 예뻐보였다.\n허나 나이가 들었나 아빠의 머리속이 매우 공감되어 슬펐다.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 자야 형성에 필요한 여러 추억들과 경험들이 예뻐보였다.\n허나 나이가 들었나 아빠의 머리속이 매우 공감되어 슬펐다.'},
#  {'title': '인사이드 아웃 2',
#   'content': '내 감성이 매말라진 것일까\n스토리가 지루한 것일까...\n내가 너무 기대한 탓일까...',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 내 감성이 매말라진 것일까\n스토리가 지루한 것일까...\n내가 너무 기대한 탓일까...'},
#  {'title': '인사이드 아웃 2',
#   'content': '한 순간이라도 쓸모 없는 마음이 있었을까. ‘구슬’ 파도가 차오르던 때, 본부조차 위태로웠던 만인을 위하여.',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 한 순간이라도 쓸모 없는 마음이 있었을까. ‘구슬’ 파도가 차오르던 때, 본부조차 위태로웠던 만인을 위하여.'},
#  {'title': '인사이드 아웃 2',
#   'content': '공감과 위로가 있었던 영화',
#   'category': 1,
#   'category_name': '영화',
#   'all_text': '영화 인사이드 아웃 2 공감과 위로가 있었던 영화'},
#  {'title': '재미있어요',
#   'content': '작지만 알차요',
#   'category': 8,
#   'category_name': '전시',
#   'all_text': '전시 재미있어요 작지만 알차요'},
#  ...]

# %% [markdown]
# ### Connect to DB to Recommendation

# %%
import os
from dotenv import load_dotenv

# .env 파일 로드
load_dotenv()

# 환경 변수 사용
db_host = os.getenv("DATABASE_HOST")
db_name = os.getenv("DATABASE_NAME")
db_user = os.getenv("DATABASE_USER")
db_password = os.getenv("DATABASE_PASSWORD")

# %%
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy import Column, Integer, String, ForeignKey, DateTime
from datetime import datetime

class Base(DeclarativeBase):
    pass
class User(Base):
    __tablename__ = "User"
    id = Column(Integer, primary_key=True)
    email = Column(String, unique=True)
    password = Column(String)

    def __repr__(self) -> str:
        return f"<User {self.id} {self.email}>"

class Profile(Base):
    __tablename__ = "Profile"
    id = Column(Integer, primary_key=True)
    userId = Column(Integer, ForeignKey("User.id"), nullable=False)
    nickname = Column(String, nullable=False)
    profilePhoto = Column(String, nullable=False)
    bio = Column(String, nullable=True)
    birthdate = Column(DateTime, nullable=True)

    def __repr__(self) -> str:
        return f"<Profile {self.id} {self.nickname} {self.userId}>"

class CulturePost(Base):
    __tablename__ = "CulturePost"
    id = Column(Integer, primary_key=True)
    title = Column(String, nullable=False)
    emoji = Column(String, nullable=False)
    date = Column(DateTime, nullable=False)
    categoryId = Column(Integer, nullable=False)
    authorId = Column(Integer, ForeignKey("User.id"), nullable=False)
    review = Column(String, nullable=False)
    disclosure = Column (String, nullable=False)
    detail1 = Column (String, nullable=True)
    detail2 = Column (String, nullable=True)
    detail3 = Column (String, nullable=True)
    detail4 = Column (String, nullable=True)
    createdAt = Column(DateTime, insert_default=datetime.now())
    updatedAt = Column(DateTime, default=datetime.now())

    def __repr__(self) -> str:
        return f"<CulturePost {self.id} {self.title} {self.emoji} {self.review}>"

class Photo(Base):
    __tablename__ = "Photo"
    id = Column(Integer, primary_key=True)
    url = Column(String, nullable=False)
    culturePostId = Column(Integer, ForeignKey("CulturePost.id"), nullable=False)

    def __repr__(self) -> str:
        return f"<Photo {self.url} {self.culturePostId}>"

# %%
from sqlalchemy import create_engine, MetaData
from sqlalchemy.orm import sessionmaker

# 데이터베이스 연결 설정
engine = create_engine(f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}/{db_name}')

# 메타데이터 객체 생성
metadata = MetaData()

# 세션 생성기 설정
Session = sessionmaker(bind=engine)
session = Session()

# Fetch data from the CulturePost table
def fetch_data_from_db():
    query = session.query(CulturePost).all()
    data = [{'title': row.title, 'content': row.review, 'category': row.categoryId} for row in query]
    return data

# Fetch all records written by the current user
def fetch_user_data_from_db(user_id):
    query = session.query(CulturePost).filter_by(authorId=user_id).all()
    user_data = [{'title': row.title, 'content': row.review, 'category': row.categoryId} for row in query]
    return user_data

# Fetch the data
data_from_db = fetch_data_from_db()

# %%
import pandas as pd

# Convert fetched data into a pandas DataFrame
df = pd.DataFrame(data_from_db)

# Mapping category IDs to category names (similar to the previous example)
category_name = [ "", "영화", "뮤지컬", "연극", "스포츠", "공연", "드라마", "책", "전시"]
df['category_name'] = df['category'].apply(lambda x: category_name[x])

# Combine the category, title, and content into one field for vectorization
df['all_text'] = df['category_name'] + ' ' + df['title'] + ' ' + df['content']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# TF-IDF vectorization
tfidf_vectorizer = TfidfVectorizer(max_features=500)
tfidf_matrix = tfidf_vectorizer.fit_transform(df['all_text'])

# Calculate cosine similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
def create_user_profile_vector(user_id):
    # Fetch all posts by the user
    user_posts = fetch_user_data_from_db(user_id)

    # Combine all posts into one large text
    combined_text = ' '.join([category_name[post['category']] + ' ' + post['title'] + ' ' + post['content'] for post in user_posts])
    print(combined_text)

    # Create a single TF-IDF vector for the combined text
    user_vector = tfidf_vectorizer.transform([combined_text])

    return user_vector

# %%
import numpy as np
def recommend(user_id):
    user_profile_vector = create_user_profile_vector(user_id)

    # Calculate similarity
    user_sim = cosine_similarity(user_profile_vector, tfidf_matrix)

    # Sort by similarity and recommend top 5
    recommended_indices = np.argsort(-user_sim[0])
    recommendations = df.iloc[recommended_indices]

    return recommendations.to_dict(orient='records')

# %%
ans = recommend(281)
print (len(ans))
print (ans[:5])
# Out:
# 드라마 선재 업고 튀어 우리가 찾던 바로 그 청춘 로맨스물. 안 본 사람은 있어도 한번만 본 사람은 없는, 늦지않게 정주행해야 하는 작품. 연출진의 계산된 연출과 각본이 유치하지 않은 설렘으로 다가온다. 드라마 선재 업고 튀어 요즘 선재업고 튀어에 빠져있습니다. 그 이유는 드라마 슬기로운 의사생활 시즌 1 따듯하고 편안한 일상물. 영화 범죄도시4 전작의 시퀀스를 그대로 따라가지만 챙길 것 다 챙기는 영악한 구성.
# 1045
# [{'title': '선재 업고 튀어', 'content': '우리가 찾던 바로 그 청춘 로맨스물. 안 본 사람은 있어도 한번만 본 사람은 없는, 늦지않게 정주행해야 하는 작품. 연출진의 계산된 연출과 각본이 유치하지 않은 설렘으로 다가온다.', 'category': 6, 'category_name': '드라마', 'all_text': '드라마 선재 업고 튀어 우리가 찾던 바로 그 청춘 로맨스물. 안 본 사람은 있어도 한번만 본 사람은 없는, 늦지않게 정주행해야 하는 작품. 연출진의 계산된 연출과 각본이 유치하지 않은 설렘으로 다가온다.'}, {'title': '선재 업고 튀어', 'content': '안 본 사람은 있어도 한 번만 본 사람은 없다. 매화 예측불가 엔딩,극본,연출,연기,ost까지 뭐하나 빠지지 않는 드라마♡ 풋풋했던 그 시절 청춘, 뜨거웠던 사랑이 그리운 분들께', 'category': 6, 'category_name': '드라마', 'all_text': '드라마 선재 업고 튀어 안 본 사람은 있어도 한 번만 본 사람은 없다. 매화 예측불가 엔딩,극본,연출,연기,ost까지 뭐하나 빠지지 않는 드라마♡ 풋풋했던 그 시절 청춘, 뜨거웠던 사랑이 그리운 분들께'}, {'title': '선재 업고 튀어', 'content': '똑똑한 드라마', 'category': 6, 'category_name': '드라마', 'all_text': '드라마 선재 업고 튀어 똑똑한 드라마'}, {'title': '선재 업고 튀어', 'content': '나쁘지않은 로맨틱 환타지. 뻔해도 주기적으로 봐줘야 연애세포 존버시켜주는 드라마', 'category': 6, 'category_name': '드라마', 'all_text': '드라마 선재 업고 튀어 나쁘지않은 로맨틱 환타지. 뻔해도 주기적으로 봐줘야 연애세포 존버시켜주는 드라마'}, {'title': '선재 업고 튀어', 'content': '2개월간 행복했어요.', 'category': 6, 'category_name': '드라마', 'all_text': '드라마 선재 업고 튀어 2개월간 행복했어요.'}]

# %% [markdown]
# ### GNN recommendation with DB

# %%
import os
from dotenv import load_dotenv

# .env 파일 로드
load_dotenv()

# 환경 변수 사용
db_host = os.getenv("DATABASE_HOST")
db_name = os.getenv("DATABASE_NAME")
db_user = os.getenv("DATABASE_USER")
db_password = os.getenv("DATABASE_PASSWORD")

# %%
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy import Column, Integer, String, ForeignKey, DateTime
from datetime import datetime

class Base(DeclarativeBase):
    pass
class User(Base):
    __tablename__ = "User"
    id = Column(Integer, primary_key=True)
    email = Column(String, unique=True)
    password = Column(String)

    def __repr__(self) -> str:
        return f"<User {self.id} {self.email}>"

class Profile(Base):
    __tablename__ = "Profile"
    id = Column(Integer, primary_key=True)
    userId = Column(Integer, ForeignKey("User.id"), nullable=False)
    nickname = Column(String, nullable=False)
    profilePhoto = Column(String, nullable=False)
    bio = Column(String, nullable=True)
    birthdate = Column(DateTime, nullable=True)

    def __repr__(self) -> str:
        return f"<Profile {self.id} {self.nickname} {self.userId}>"

class CulturePost(Base):
    __tablename__ = "CulturePost"
    id = Column(Integer, primary_key=True)
    title = Column(String, nullable=False)
    emoji = Column(String, nullable=False)
    date = Column(DateTime, nullable=False)
    categoryId = Column(Integer, nullable=False)
    authorId = Column(Integer, ForeignKey("User.id"), nullable=False)
    review = Column(String, nullable=False)
    disclosure = Column (String, nullable=False)
    detail1 = Column (String, nullable=True)
    detail2 = Column (String, nullable=True)
    detail3 = Column (String, nullable=True)
    detail4 = Column (String, nullable=True)
    createdAt = Column(DateTime, insert_default=datetime.now())
    updatedAt = Column(DateTime, default=datetime.now())

    def __repr__(self) -> str:
        return f"<CulturePost {self.id} {self.title} {self.emoji} {self.review}>"

class Photo(Base):
    __tablename__ = "Photo"
    id = Column(Integer, primary_key=True)
    url = Column(String, nullable=False)
    culturePostId = Column(Integer, ForeignKey("CulturePost.id"), nullable=False)

    def __repr__(self) -> str:
        return f"<Photo {self.url} {self.culturePostId}>"

# %%
from sqlalchemy import create_engine, MetaData
from sqlalchemy.orm import sessionmaker

# 데이터베이스 연결 설정
engine = create_engine(f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}/{db_name}')

# 메타데이터 객체 생성
metadata = MetaData()

# 세션 생성기 설정
Session = sessionmaker(bind=engine)
session = Session()

# Fetch data from the CulturePost table with all necessary columns
def fetch_data_from_db():
    query = session.query(CulturePost).all()
    data = [{
        'id': row.id,
        'title': row.title,
        'emoji': row.emoji,
        'date': row.date,
        'categoryId': row.categoryId,
        'authorId': row.authorId,
        'review': row.review,
        'disclosure': row.disclosure,
        'detail1': row.detail1,
        'detail2': row.detail2,
        'detail3': row.detail3,
        'detail4': row.detail4
    } for row in query]
    return data

# Fetch all records written by the current user with all necessary columns
def fetch_user_data_from_db(user_id):
    query = session.query(CulturePost).filter_by(authorId=user_id).all()
    user_data = [{
        'id': row.id,
        'title': row.title,
        'emoji': row.emoji,
        'date': row.date,
        'categoryId': row.categoryId,
        'authorId': row.authorId,
        'review': row.review,
        'disclosure': row.disclosure,
        'detail1': row.detail1,
        'detail2': row.detail2,
        'detail3': row.detail3,
        'detail4': row.detail4
    } for row in query]
    return user_data

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# 데이터 준비 (DB에서 가져온 데이터를 바탕으로)
data_from_db = fetch_data_from_db()  # DB에서 가져온 콘텐츠 데이터
df = pd.DataFrame(data_from_db)
category_name = ["", "영화", "뮤지컬", "연극", "스포츠", "공연", "드라마", "책", "전시"]
df['category_name'] = df['categoryId'].apply(lambda x: category_name[x])
df['all_text'] = df['category_name'] + ' ' + df['title'] + ' ' + df['review']

# TF-IDF 벡터화
tfidf_vectorizer = TfidfVectorizer(max_features=500)
tfidf_matrix = tfidf_vectorizer.fit_transform(df['all_text'])

# Calculate cosine similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
import torch
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
import torch.nn.functional as F
import numpy as np

# GCN 모델 정의
class GCN(torch.nn.Module):
    def __init__(self):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(500, 16)  # TF-IDF의 max_features = 500
        self.conv2 = GCNConv(16, 16)
        self.conv3 = GCNConv(16, 500)  # 차원 다시 확장

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        return x

# 유저 벡터와 전체 그래프 노드를 결합하여 학습 데이터 생성
def create_combined_graph_data(user_vector, data):
    # 유저 벡터의 크기를 맞춰 2차원으로 변환
    user_node = user_vector.squeeze(0)  # 불필요한 차원 제거

    # 유저 노드를 기존 TF-IDF 매트릭스의 한 노드로 추가
    combined_x = torch.cat([data.x, user_node.unsqueeze(0)], dim=0)

    # 엣지 구성 (유저 노드와 기존 노드 간 유사도 기반 엣지 추가)
    user_edges = [[i, len(data.x)] for i in range(len(data.x))]  # 유저 노드를 새로운 노드로 추가
    user_edge_index = torch.tensor(user_edges, dtype=torch.long).t().contiguous()

    combined_edge_index = torch.cat([data.edge_index, user_edge_index], dim=1)

    return Data(x=combined_x, edge_index=combined_edge_index)

def create_graph_data():
    # TF-IDF 벡터화된 데이터 사용 (이미 있는 tfidf_matrix와 cosine_sim 사용)
    # 엣지(Edge) 생성 (코사인 유사도에 기반)
    edge_index = torch.tensor([
        [i, j] for i in range(len(cosine_sim)) for j in range(len(cosine_sim)) if cosine_sim[i, j] > 0.5
    ], dtype=torch.long).t().contiguous()

    # TF-IDF 벡터를 노드 특징으로 사용
    x = torch.tensor(tfidf_matrix.toarray(), dtype=torch.float)

    # 그래프 데이터 객체 생성
    data = Data(x=x, edge_index=edge_index)

    return data

def train_gnn(data):
    model = GCN()  # GCN 모델 생성
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)  # 옵티마이저 설정

    # 모델 학습 함수 정의
    def train():
        model.train()
        optimizer.zero_grad()
        out = model(data)  # GCN을 통해 노드 임베딩 계산
        loss = F.mse_loss(out, data.x)  # 노드 특징 복원을 위한 MSE Loss
        loss.backward()
        optimizer.step()

    # 학습 반복
    for epoch in range(100):  # 100회 반복 학습
        train()

    return model  # 학습 완료된 모델 반환

def create_user_profile_vector(user_id):
    # 유저가 작성한 모든 기록을 가져옴
    user_posts = fetch_user_data_from_db(user_id)

    # 카테고리, 제목, 내용을 결합하여 하나의 텍스트로 만듦
    combined_text = ' '.join([category_name[post['categoryId']] + ' ' + post['title'] + ' ' + post['review'] for post in user_posts])
    print(combined_text)
    
    # 결합된 텍스트를 TF-IDF 벡터화
    user_vector = tfidf_vectorizer.transform([combined_text])

    return torch.tensor(user_vector.toarray(), dtype=torch.float)

# 추천 함수 수정
def recommend(user_id):
    # 기존 데이터셋으로 그래프 생성
    data = create_graph_data()

    # GNN 학습
    trained_model = train_gnn(data)

    # 유저 프로필 벡터 생성
    user_vector = create_user_profile_vector(user_id)
    
    # 유저 벡터와 전체 노드 결합한 그래프 데이터 생성
    combined_data = create_combined_graph_data(user_vector, data)

    # GNN 모델로 유저 임베딩 추출
    trained_model.eval()  # 모델 평가 모드
    user_embedding = trained_model(combined_data)

    # 유저 임베딩과 모든 노드 간의 유사도 계산
    user_sim = cosine_similarity(user_embedding[-1].detach().numpy().reshape(1, -1), data.x.detach().numpy())

    # 유사한 순으로 정렬하여 추천
    recommended_indices = np.argsort(-user_sim[0])
    recommendations = df.iloc[recommended_indices]

    return recommendations.to_dict(orient='records')

# %%
ret = recommend(1)
print(len(ret))
print(ret[:5])
# Out:
# 영화 파일럿 역시 믿고 보는 코미디 영화!
# 1045
# [{'id': 1173, 'title': '인사이드 아웃 2', 'emoji': '📺', 'date': Timestamp('2024-08-26 00:00:00'), 'categoryId': 1, 'authorId': 393, 'review': 'Inside Out 2', 'disclosure': 'PUBLIC', 'detail1': '인사이드 아웃 2', 'detail2': None, 'detail3': '애니메이션, 가족', 'detail4': None, 'category_name': '영화', 'all_text': '영화 인사이드 아웃 2 Inside Out 2'}, {'id': 1110, 'title': '인사이드 아웃 2', 'emoji': '📺', 'date': Timestamp('2024-07-12 00:00:00'), 'categoryId': 1, 'authorId': 352, 'review': '픽사는 단순한 진리를 따듯한 영상미로 손쉽게 가슴으로 밀어 넣어주는 기술자들이다.', 'disclosure': 'PUBLIC', 'detail1': '인사이드 아웃 2', 'detail2': None, 'detail3': '애니메이션, 가족', 'detail4': None, 'category_name': '영화', 'all_text': '영화 인사이드 아웃 2 픽사는 단순한 진리를 따듯한 영상미로 손쉽게 가슴으로 밀어 넣어주는 기술자들이다.'}, {'id': 1100, 'title': '인사이드 아웃 2', 'emoji': '📺', 'date': Timestamp('2024-06-06 00:00:00'), 'categoryId': 1, 'authorId': 359, 'review': "남들이 생각하는 원래의 '나'란 무엇인가", 'disclosure': 'PUBLIC', 'detail1': '인사이드 아웃 2', 'detail2': None, 'detail3': '애니메이션, 가족', 'detail4': None, 'category_name': '영화', 'all_text': "영화 인사이드 아웃 2 남들이 생각하는 원래의 '나'란 무엇인가"}, {'id': 1112, 'title': '인사이드 아웃 2', 'emoji': '📺', 'date': Timestamp('2024-08-29 00:00:00'), 'categoryId': 1, 'authorId': 158, 'review': '추상적인 것들을 개념화하고, 실체화하는 픽사의 놀라운 창의력', 'disclosure': 'PUBLIC', 'detail1': '인사이드 아웃 2', 'detail2': None, 'detail3': '애니메이션, 가족', 'detail4': None, 'category_name': '영화', 'all_text': '영화 인사이드 아웃 2 추상적인 것들을 개념화하고, 실체화하는 픽사의 놀라운 창의력'}, {'id': 1118, 'title': '인사이드 아웃 2', 'emoji': '📺', 'date': Timestamp('2024-08-07 00:00:00'), 'categoryId': 1, 'authorId': 216, 'review': '기대됩니당😻', 'disclosure': 'PUBLIC', 'detail1': '인사이드 아웃 2', 'detail2': None, 'detail3': '애니메이션, 가족', 'detail4': None, 'category_name': '영화', 'all_text': '영화 인사이드 아웃 2 기대됩니당😻'}]
